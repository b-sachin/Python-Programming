# %%
 import pandas as pd

# %%
titanic = pd.read_csv(r"C:\Users\Admin\Documents\Sachin\dataset\titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic.dtypess)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 type(titanic.dtypess)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtypess'

# %%
dy = titanic.dtypes

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
dy[2]
# Out:
# dtype('int64')

# %%
l = [0,1,2,3,4,5,"sach","b"]

# %%
l
# Out:
# [0, 1, 2, 3, 4, 5, 'sach', 'b']

# %%
l[4]
# Out:
# 4

# %%
l[6]
# Out:
# 'sach'

# %%
dy[2]
# Out:
# dtype('int64')

# %%
dy[2:5]
# Out:
# Pclass     int64
# Name      object
# Sex       object
# dtype: object

# %%
dy[1:50:2]
# Out:
# Survived      int64
# Name         object
# Age         float64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic["Age"][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
titanic["Age"][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Age"][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 titanic["Age"][-1]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
# ...

# %%
titanic["Age"][::2]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 6      54.0
# 8      27.0
#        ...
# 882    22.0
# 884    25.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 446, dtype: float64

# %%
list(titanic['Age'][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan,
#  16.0,
#  nan,
#  44.0,
#  26.0,
#  1.0,
#  nan,
#  nan,
#  61.0,
#  1.0,
#  56.0,
#  nan,
#  30.0,
#  nan,
#  9.0,
#  4.0,
#  nan,
#  40.0,
#  32.0,
#  19.0,
#  44.0,
#  nan,
#  nan,
#  28.0,
#  34.0,
#  18.0,
#  32.0,
#  16.0,
#  24.0,
#  22.0,
#  nan,
#  27.0,
#  32.0,
#  16.0,
#  51.0,
#  38.0,
#  19.0,
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.dtypes[titanic.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic[titanic.dtypes[titanic.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic[titanic.dtypes[titanic.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic_cat = titanic[titanic.dtypes[titanic.dtypes == 'object'].index]

# %%
titanic_cat
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic["PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
titanic['PassengerId','Survived']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PassengerId', 'Survived')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
titanic[['PassengerId','Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
titanic['PassengerId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
titanic[['PassengerId']]
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]

# %%
titanic['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic['Age'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
import numpy as np

# %%
np.where(titanic['Age'].isnull())
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_age_null = np.where(titanic['Age'].isnull())

# %%
titanic_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic.iloc[titanic_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
type(titanic.iloc[6])
# Out:
# pandas.core.series.Series

# %%
titanic.iloc[[1,2,3,4,5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
titanic[titanic['Fare']==max(titanic['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
np.where(titanic['Fare']==max(titanic['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
titanic.iloc[np.where(titanic['Fare']==max(titanic['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic.iloc[np.where(titanic['Fare']==max(titanic['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic.iloc[np.where(titanic['Age']==24)]
# Out:
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
# 199          200         0       2
# 210          211         0       3
# 234          235         0       2
# 247          248         1       2
# 293          294         0       3
# 294          295         0       3
# 310          311         1       1
# 316          317         1       2
# 341          342         1       1
# 345          346         1       2
# 369          370         1       1
# 394          395         1       3
# 437          438         1       2
# 499          500         0       3
# 514          515         0       3
# 565          566         0       3
# 600          601         1       2
# 615          616         1       2
# 641          642         1       1
# 655          656         0       2
# ...

# %%
titanic.iloc[np.where(titanic['Age']==24)]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
titanic.iloc[np.where(titanic['Cabin'].isnull())]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic.iloc[np.where(titanic['Cabin'].isnull())][['Age','Cabin']]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.iloc[np.where((titanic.Sex == 'male') & (titanic.Survived == 1))]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titanic.iloc[np.where((titanic.Sex == 'male') & (titanic.Survived == 1))]['Name']
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
titanic.loc[(titanic.Sex == 'male') & (titanic.Survived == 1)]['Name']
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
titanic.Name[(titanic.Sex == 'male') & (titanic.Survived == 1)]
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
titanic['new_col'] = "sach"

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S    sach
# 1      0          PC 17599  71.2833   C85        C    sach
# 2      0  STON/O2. 3101282   7.9250   NaN        S    sach
# 3      0            113803  53.1000  C123        S    sach
# ...

# %%
l = [1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = {'Key':1,'Name':'sach','address':'mumbai'}

# %%
d
# Out:
# {'Key': 1, 'Name': 'sach', 'address': 'mumbai'}

# %%
pd.DataFrame(d,index=["One","Two","Three"])
# Out:
#        Key  Name address
# One      1  sach  mumbai
# Two      1  sach  mumbai
# Three    1  sach  mumbai

# %%
pd.Series(d)
# Out:
# Key             1
# Name         sach
# address    mumbai
# dtype: object

# %%
arr = np.random.randn(3,4)

# %%
arr
# Out:
# array([[-0.88348458, -1.38858839, -0.05465799, -1.31766793],
#        [-0.51158189, -0.64692929,  1.19309629,  1.42318823],
#        [ 1.18668377,  0.48543276, -0.1490281 , -1.43434002]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -0.883485 -1.388588 -0.054658 -1.317668
# 1 -0.511582 -0.646929  1.193096  1.423188
# 2  1.186684  0.485433 -0.149028 -1.434340

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 pd.Series(arr)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:470, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     468         data = data.copy()
#     469 else:
# --> 470     data = sanitize_array(data, index, dtype, copy)
#     472     manager = get_option("mode.data_manager")
#     473     if manager == "block":
#
# File ~\anaconda3\lib\site-packages\pandas\core\construction.py:647, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     644             subarr = cast(np.ndarray, subarr)
#     645             subarr = maybe_infer_to_datetimelike(subarr)
# --> 647 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     649 if isinstance(subarr, np.ndarray):
# ...

# %%
ser = pd.Series(np.array([1,2,3,4,5]), index = ['a','b','c','d','e'])

# %%
ser
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 ser
#
# NameError: name 'ser' is not defined

# %%
ser['c']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 ser['c']
#
# NameError: name 'ser' is not defined

# %%
ser.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 ser.iloc[0]
#
# NameError: name 'ser' is not defined

# %%
ser.loc['a']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 ser.loc['a']
#
# NameError: name 'ser' is not defined

# %%
ser = pd.Series(np.array([1,2,3,4,5]), index = [100,200,300,400,500])

# %%
ser
# Out:
# 100    1
# 200    2
# 300    3
# 400    4
# 500    5
# dtype: int32

# %% [markdown]
# ### Difference Between loc and iloc

# %%
ser.iloc[200]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 ser.iloc[200]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser.loc[200]
# Out:
# 2

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/master/nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
gk = df.groupby('Team')

# %%
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
gk.get_group('Boston Celtics')
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
gkk = df.groupby(['Team', 'Position'])

# %%
gkk.first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...

# %%
#import the pandas library
import pandas as pd

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

print( df)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
print(df.groupby(["car"]).mean())
# Out:
#          co2
# car
# Ford   100.5
# Skoda   97.0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13480\3362750703.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby(["car"]).mean())

# %%
print(df.groupby('Team'))

# %%
df.groupby('Team').groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %%
df.groupby(['Team','Year']).groups
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10], ('kings', 2015): [5]}

# %%
grouped = df.groupby('Year')

# %%
for i,j in grouped:
    print(i)
    print(j)
# Out:
# 2014
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
# 2015
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
# 2016
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
# 2017
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
for i in grouped:
    print(i)
# Out:
# (2014,      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701)
# (2015,       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804)
# (2016,      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694)
# (2017,       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690)

# %%
for _,j in grouped:
    print(j)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
grouped = df.groupby('Year')
grouped.get_group(2014)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %%
grouped.get_group(2015)
# Out:
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
gk = df.groupby('Year')

# %%
gk['Points'].agg(np.mean)
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
gk = df.groupby('Team')

# %%
gk.agg(np.size)
# Out:
#         Rank  Year  Points
# Team
# Devils     2     2       2
# Kings      3     3       3
# Riders     4     4       4
# Royals     2     2       2
# kings      1     1       1

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
gk = df.groupby('Team')

# %%
gk.groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10], 'kings': [5]}

# %%
gk['Points'].agg([np.sum,np.mean,np.std])
# Out:
#          sum        mean         std
# Team
# Devils  1536  768.000000  134.350288
# Kings   2285  761.666667   24.006943
# Riders  3049  762.250000   88.567771
# Royals  1505  752.500000   72.831998
# kings    812  812.000000         NaN

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
gk = df.groupby('Team')

# %%
score= lambda x: (x - x.mean()) / x.std() *10

# %%
gk.transform(score)
# Out:
#          Rank       Year     Points
# 0  -15.000000 -11.618950  12.843272
# 1    5.000000  -3.872983   3.020286
# 2   -7.071068  -7.071068   7.071068
# 3    7.071068   7.071068  -7.071068
# 4   11.547005 -10.910895  -8.608621
# 5         NaN        NaN        NaN
# 6   -5.773503   2.182179  -2.360428
# 7   -5.773503   8.728716  10.969049
# 8    5.000000   3.872983  -7.705963
# 9    7.071068  -7.071068  -7.071068
# 10  -7.071068   7.071068   7.071068
# 11   5.000000  11.618950  -8.157595

# %%
gk['Rank'].agg([np.sum,np.mean,np.std])
# Out:
#         sum      mean       std
# Team
# Devils    5  2.500000  0.707107
# Kings     5  1.666667  1.154701
# Riders    7  1.750000  0.500000
# Royals    5  2.500000  2.121320
# kings     4  4.000000       NaN

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %% [markdown]
# ### return the teams which have participated three or more times in IPL.

# %%
df.groupby('Team').filter(lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690
